# %%
import pandas as pd

df = pd.read_csv("./data/features.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 27 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Name                                      982 non-null    object
#  1   HRID                                      982 non-null    int64
#  2   Address                                   982 non-null    object
#  3   Community                                 982 non-null    object
#  4   Ward                                      982 non-null    int64
#  5   Resource Type                             969 non-null    object
#  6   Year of Construction                      978 non-null    object
#  7   Development Era                           982 non-null    object
#  8   Architectural Style                       806 non-null    object
#  9   Architect                                 759 non-null    object
#  10  Builder                                   849 non-null    object
#  11  Original Use                              981 non-null    object
#  12  Provincial                                982 non-null    object
#  13  Municipal                                 982 non-null    object
#  14  Alternate Names                           378 non-null    object
#  15  Is Demolished                             938 non-null    object
#  16  Is Decommissioned                         977 non-null    object
#  17  Significance Summary                      855 non-null    object
#  18  Description                               812 non-null    object
#  19  Heritage Value                            978 non-null    object
#  20  Character Defining Elements               805 non-null    object
#  21  Occupants (Henderson's Directory Search)  616 non-null    object
#  22  Owners (Historic Title Search)            569 non-null    object
#  23  Sources List                              714 non-null    object
#  24  Additional Heritage Value Information     171 non-null    object
#  25  x                                         982 non-null    float64
#  26  y                                         982 non-null    float64
# dtypes: float64(2), int64(2), object(23)
# memory usage: 207.3+ KB

# %%
'''
 0   Name                                      : 977/982 -> String 
 1   HRID                                      : 982/982 -> Integer 
 2   Address                                   : 949/982 -> String
 3   Community                                 : 100/982 -> String (categorical encoding maybe) ***
 4   Ward                                      : 14 /982 -> Integer (likely representing an area of some kind) ***
 5   Resource Type                             : 8  /969 -> String (categorical) ***
 6   Year of Construction                      : 118/978 -> Integer
 7   Development Era                           : 12 /982 -> String (int range) Categorical
 8   Architectural Style                       : 43 /806 -> String ***
 9   Architect                                 : 278/982 -> String
 10  Builder                                   : 424/849 -> String
 11  Original Use                              : 14 /981 -> String (categorical) ***
 12  Provincial                                : 2  /982 -> Bool
 13  Municipal                                 : 2  /982 -> Bool 
 14  Alternate Names                           : 370/982 -> String
 15  Is Demolished                             : 2  /982 -> Bool
 16  Is Decommissioned                         : 2  /982 -> Bool
 17  Significance Summary                      : This and below seem irrelevant for now
 18  Description                               :
 19  Heritage Value                            : 
 20  Character Defining Elements               :
 21  Occupants (Henderson's Directory Search)  : 
 22  Owners (Historic Title Search)            :
 23  Sources List                              :
 24  Additional Heritage Value Information     :
 25  x                                         :
 26  y                                         :

'''
# Out:
# "\n 0   Name                                      : 977/982 -> String \n 1   HRID                                      : 982/982 -> Integer \n 2   Address                                   : 949/982 -> String\n 3   Community                                 : 100/982 -> String (categorical encoding maybe) ***\n 4   Ward                                      : 14 /982 -> Integer (likely representing an area of some kind) ***\n 5   Resource Type                             : 8  /969 -> String (categorical) ***\n 6   Year of Construction                      : 118/978 -> Integer\n 7   Development Era                           : 12 /982 -> String (int range) Categorical\n 8   Architectural Style                       : 43 /806 -> String ***\n 9   Architect                                 : 278/982 -> String\n 10  Builder                                   : 424/849 -> String\n 11  Original Use                              : 14 /981 -> String (categorical) ***\n 12  Provincial                                : 2  /982 -> Bool\n 13  Municipal                                 : 2  /982 -> Bool \n 14  Alternate Names                           : 370/982 -> String\n 15  Is Demolished                             : 2  /982 -> Bool\n 16  Is Decommissioned                         : 2  /982 -> Bool\n 17  Significance Summary                      : This and below seem irrelevant for now\n 18  Description                               :\n 19  Heritage Value                            : \n 20  Character Defining Elements               :\n 21  Occupants (Henderson's Directory Search)  : \n 22  Owners (Historic Title Search)            :\n 23  Sources List                              :\n 24  Additional Heritage Value Information     :\n 25  x                                         :\n 26  y                                         :\n\n"

# %%
col_to_drop = ["Name", "HRID", "Address", "Alternate Names", "Builder", "Architect"]

df.drop(columns=df.iloc[:,17:27], inplace=True)



df.drop(columns=col_to_drop, inplace=True)

# %%
df.info()

df["Original Use"].fillna(df["Original Use"].mode()[0], inplace=True)

print(df["Original Use"].value_counts())
df[df["Original Use"].isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Community             982 non-null    object
#  1   Ward                  982 non-null    int64
#  2   Resource Type         969 non-null    object
#  3   Year of Construction  978 non-null    object
#  4   Development Era       982 non-null    object
#  5   Architectural Style   806 non-null    object
#  6   Original Use          981 non-null    object
#  7   Provincial            982 non-null    object
#  8   Municipal             982 non-null    object
#  9   Is Demolished         938 non-null    object
#  10  Is Decommissioned     977 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 84.5+ KB
# Original Use
# Residence                       412
# Commerce                        165
# Religion, Ritual and Funeral     71
# Transport                        63
# Mixed Use                        59
# Education                        44
# Industry                         44
# Leisure                          42
# Community                        21
# Government                       19
# Defence                          19
# Food Supply                      14
# Health and Research               6
# Archaeology                       3
# Name: count, dtype: int64
# C:\Users\canmo\AppData\Local\Temp\ipykernel_23968\1358948671.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Original Use"].fillna(df["Original Use"].mode()[0], inplace=True)
# Empty DataFrame
# Columns: [Community, Ward, Resource Type, Year of Construction, Development Era, Architectural Style, Original Use, Provincial, Municipal, Is Demolished, Is Decommissioned]
# Index: []

# %%
df[df["Development Era"] == "1885 to 1905 (Railway/Early Settlement)"]
# Out:
#                     Community  Ward                Resource Type  \
# 42                   BELTLINE     8  Community Historic Resource
# 44   DOWNTOWN COMMERCIAL CORE     7  City Wide Historic Resource
# 48   DOWNTOWN COMMERCIAL CORE     7  City Wide Historic Resource
# 54                POINT MCKAY     7  Community Historic Resource
# 82   DOWNTOWN COMMERCIAL CORE     7  City Wide Historic Resource
# ..                        ...   ...                          ...
# 918     MANCHESTER INDUSTRIAL     9  City Wide Historic Resource
# 923                 INGLEWOOD     9  City Wide Historic Resource
# 940                   SUNALTA     8  City Wide Historic Resource
# 947                  BELTLINE     8  City Wide Historic Resource
# 959                 INGLEWOOD     9  Community Historic Resource
#
#     Year of Construction                          Development Era  \
# 42                  1905  1885 to 1905 (Railway/Early Settlement)
# 44                  1903  1885 to 1905 (Railway/Early Settlement)
# 48                  1888  1885 to 1905 (Railway/Early Settlement)
# 54                  1905  1885 to 1905 (Railway/Early Settlement)
# 82                  1904  1885 to 1905 (Railway/Early Settlement)
# ..                   ...                                      ...
# 918                 1900  1885 to 1905 (Railway/Early Settlement)
# 923                 1886  1885 to 1905 (Railway/Early Settlement)
# 940                 1904  1885 to 1905 (Railway/Early Settlement)
# 947                 1905  1885 to 1905 (Railway/Early Settlement)
# 959                 1903  1885 to 1905 (Railway/Early Settlement)
#
#        Architectural Style                  Original Use Provincial Municipal  \
# 42      Queen Anne Revival                     Residence         No        No
# 44    Edwardian Commercial                      Commerce         No        No
# 48              Italianate                      Commerce         No       Yes
# 54                     NaN                     Residence         No        No
# 82       Classical Revival                      Commerce         No        No
# ..                     ...                           ...        ...       ...
# 918      Edwardian Cottage  Religion, Ritual and Funeral         No        No
# 923       Georgian Revival                     Residence         No        No
# 940  Edwardian Gable-Front                     Residence         No        No
# 947   Edwardian Commercial                     Mixed Use         No        No
# 959      Edwardian Cottage                     Residence         No        No
#
#     Is Demolished Is Decommissioned
# 42             No                No
# 44             No                No
# 48             No                No
# 54             No                No
# 82             No                No
# ..            ...               ...
# 918            No                No
# 923            No                No
# 940            No                No
# 947           Yes                No
# 959            No                No
#
# [76 rows x 11 columns]

# %%
# Save original before filling
df_before = df["Year of Construction"].copy()

# Your fillna operation
def extract_median_year(era):
    years = re.findall(r"\d{4}", str(era))
    if len(years) == 2:
        return (int(years[0]) + int(years[1])) // 2
    elif len(years) == 1:
        return int(years[0])
    return None

df["Year of Construction"] = df["Year of Construction"].fillna(
    df["Development Era"].map(extract_median_year)
)
# Compare before and after for rows that were originally NaN
mask = df_before.isna()
pd.DataFrame({
    "Development Era": df.loc[mask, "Development Era"],
    "Before": df_before[mask],
    "After": df["Year of Construction"][mask]
})
# Out:
# Empty DataFrame
# Columns: [Community, Ward, Resource Type, Year of Construction, Development Era, Architectural Style, Original Use, Provincial, Municipal, Is Demolished, Is Decommissioned]
# Index: []

# %%
#df.info()
import re

def extract_median_year(val):
    years = re.findall(r"\d{4}", str(val))
    if len(years) >= 2:
        return (int(years[0]) + int(years[-1])) // 2
    elif len(years) == 1:
        return int(years[0])
    return None

df["Year of Construction"] = df["Year of Construction"].map(extract_median_year)
df["Year of Construction"][df["Year of Construction"].apply(lambda x: isinstance(x, str))].unique()
# Out:
# array([], dtype=int64)

# %%
df[df["Year of Construction"].isin([1000, 7000])]
# Out:
#           Community  Ward                Resource Type  Year of Construction  \
# 10          TUSCANY     1  City Wide Historic Resource                  1000
# 661  NOSE HILL PARK     4  City Wide Historic Resource                  7000
# 688       PATTERSON     6  City Wide Historic Resource                  1000
#
#                                  Development Era Architectural Style  \
# 10       ca. 1,500 – 200 years ago (Late Period)                 NaN
# 661  ca. 7,750 – 1,500 years ago (Middle Period)                 NaN
# 688      ca. 1,500 – 200 years ago (Late Period)                 NaN
#
#     Original Use Provincial Municipal Is Demolished Is Decommissioned
# 10   Archaeology         No        No            No                No
# 661  Archaeology         No       Yes            No                No
# 688  Archaeology         No        No            No                No

# %%
import matplotlib.pyplot as plt

df_clean = df.dropna(subset=["Year of Construction"])

year_counts = df["Year of Construction"].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.scatter(year_counts.index, year_counts.values, alpha=0.6)
plt.xlabel("Year of Construction")
plt.ylabel("Frequency")
plt.title("Frequency of Year of Construction")
plt.tight_layout()
plt.show()
